# %%
import numpy as np
import pandas as pd
import statistics
import seaborn as sns
import os
import subprocess
import shutil
import plotly.express as px
import sys
sys.path.append('/gpfs/commons/home/mgarbulowski/homic_package/src') 
from homic import file_readers, kraken2, process_data, make_plots
from collections import Counter
from scipy import stats
import matplotlib.pyplot as plt
import re
# Out:
# homic package imported

# %%
# list of samples
samp_list = ["KP003","KP004","KP005","KP008","KP010","KP011","KP012","KP013","KP016","KP021","KP024","KP025","KP026",
         "KP027","KP029","KP033","KP035","KP037","KP038","KP040","KP041","KP046","KP047","KP048","KP049","KP052"]
all_samps = np.array(samp_list)

path_in =  "/gpfs/commons/home/mgarbulowski/016_proj_shm/metagenomes_lib/saturation_analysis_x4/"   # folder containing all ID folders
reads_nos = process_data.filenams_to_readsnos(path_in, samp_list) # takes reads number from file names

# %%
sample_ids = list(reads_nos.keys())
values = [lst[-1]*2 for lst in reads_nos.values()]
sample_ids, values = zip(*sorted(zip(sample_ids, values), key=lambda x: x[1]))

plt.figure(figsize=(8, 4))
plt.bar(sample_ids, values)
plt.ylabel("Total number of reads")
plt.xlabel("Sample ID")
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
#df_satur = process_data.species_richness_table(samp_list, reads_nos, path_in,
#                               evalue=1e-50, pident=0.99, taxa="species", tail_points=4, slope_thresh=0.00002)
#print(df_satur)

# %%
#df_satur.to_csv("/gpfs/commons/home/mgarbulowski/016_proj_shm/metagenomes_lib/saturation_analysis_x4/saturation_summary.csv", index=False)

# %%
df_satur = process_data.species_richness_table(samp_list, reads_nos, path_in,
                               evalue=1e-50, pident=0.99, taxa="species", tail_points=5, slope_thresh=0.00002)
print(df_satur)
# Out:
#    Sample  Good's coverage Coverage status  Chao1 ratio   Chao1 status  \
# 0   KP003         0.997357       Saturated     0.662251      Saturated
# 1   KP004         0.995704          Almost     0.666730      Saturated
# 2   KP005         0.990161          Almost     0.573831  Not saturated
# 3   KP008         0.996468       Saturated     0.660933      Saturated
# 4   KP010         0.996683       Saturated     0.634618  Not saturated
# 5   KP011         0.996212       Saturated     0.644184  Not saturated
# 6   KP012         0.973512          Almost     0.599324  Not saturated
# 7   KP013         0.995777          Almost     0.621184  Not saturated
# 8   KP016         0.995537          Almost     0.697364      Saturated
# 9   KP021         0.994489          Almost     0.644215  Not saturated
# 10  KP024         0.995963          Almost     0.621423  Not saturated
# 11  KP025         0.995253          Almost     0.653030      Saturated
# 12  KP026         0.995255          Almost     0.574829  Not saturated
# 13  KP027         0.995945          Almost     0.647261      Saturated
# 14  KP029         0.994355          Almost     0.690216      Saturated
# 15  KP033         0.995328          Almost     0.625305  Not saturated
# 16  KP035         0.995740          Almost     0.578037  Not saturated
# 17  KP037         0.995479          Almost     0.600099  Not saturated
# 18  KP038         0.993624          Almost     0.605390  Not saturated
# 19  KP040         0.995931          Almost     0.662563      Saturated
# 20  KP041         0.996867       Saturated     0.687952      Saturated
# 21  KP046         0.992994          Almost     0.617957  Not saturated
# 22  KP047         0.995100          Almost     0.599723  Not saturated
# 23  KP048         0.995108          Almost     0.615198  Not saturated
# 24  KP049         0.993045          Almost     0.642960  Not saturated
# 25  KP052         0.995093          Almost     0.580463  Not saturated
#
#     Tail slope   Slope status
# 0     0.000035  Not saturated
# 1     0.000049  Not saturated
# 2     0.000020  Not saturated
# 3     0.000030  Not saturated
# 4     0.000035  Not saturated
# 5     0.000038  Not saturated
# 6     0.000098  Not saturated
# 7     0.000038  Not saturated
# 8     0.000027  Not saturated
# 9     0.000069  Not saturated
# 10    0.000032  Not saturated
# 11    0.000046  Not saturated
# 12    0.000040  Not saturated
# 13    0.000018      Saturated
# 14    0.000031  Not saturated
# 15    0.000041  Not saturated
# 16    0.000081  Not saturated
# 17    0.000053  Not saturated
# 18    0.000060  Not saturated
# 19    0.000021  Not saturated
# 20    0.000028  Not saturated
# 21    0.000041  Not saturated
# 22    0.000033  Not saturated
# 23    0.000071  Not saturated
# 24    0.000052  Not saturated
# 25    0.000041  Not saturated

# %%
sample_ids = list(reads_nos.keys())
values = df_satur["Tail slope"]
sample_ids, values = zip(*sorted(zip(sample_ids, values), key=lambda x: x[1]))

plt.figure(figsize=(8, 4))
plt.bar(sample_ids, values)
plt.ylabel("Tail slope")
plt.xlabel("Sample ID")
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

sample_ids = list(reads_nos.keys())
values = df_satur["Good's coverage"]-0.95
sample_ids, values = zip(*sorted(zip(sample_ids, values), key=lambda x: x[1]))

plt.figure(figsize=(8, 4))
plt.bar(sample_ids, values, bottom=0.95)
plt.ylabel("Good's coverage")
plt.xlabel("Sample ID")
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

sample_ids = list(reads_nos.keys())
values = df_satur["Chao1 ratio"]
sample_ids, values = zip(*sorted(zip(sample_ids, values), key=lambda x: x[1]))

plt.figure(figsize=(8, 4))
plt.bar(sample_ids, values)
plt.ylabel("Chao1 ratio")
plt.xlabel("Sample ID")
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
# more restrictive pruning
ev = 1e-200
pi = 0.99
path_out = path_in + "figs/saturation_curve_seqx4_ev" + str(ev) + "_pi" + str(pi) + ".png"
#make_plots.saturation_curves(samp_list, reads_nos, path_in, path_out, evalue = ev, pident = pi, taxa="species")

# %%
# less restrictive pruning
ev = 1e-50
pi = 0.99
path_out = path_in + "figs/saturation_curve_seqx4_ev" + str(ev) + "_pi" + str(pi) + ".png"
#make_plots.saturation_curves(samp_list, reads_nos, path_in, path_out, evalue = ev, pident = pi, taxa="species")

# %%
ev = 1e-50
pi = 0.99
path_out = path_in + "figs/multi_saturation_curve_seqx4_ev" + str(ev) + "_pi" + str(pi) + ".png"
make_plots.multi_saturation_curves(samp_list, reads_nos, path_in, path_out, evalue = ev, pident = pi, taxa="species")
