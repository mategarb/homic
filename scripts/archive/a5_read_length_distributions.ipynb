# %%
import numpy as np
import pandas as pd
import statistics
import os
import subprocess
import shutil
from collections import Counter
from scipy import stats
import plotly as pty
import seaborn as sns
import matplotlib.pyplot as plt

import sys
sys.path.append('/gpfs/commons/home/mgarbulowski/homic_package/src') 
from homic import file_readers, kraken2, process_data
# Out:
# homic package imported

# %%
he,re,qu = file_readers.fastq("/gpfs/commons/home/mgarbulowski/016_proj_shm/data_polyA_comparison/20250925_1858_P2S-02509-B_PBA50717_5e6e2eeb_trimmed.fastq")
lns = [len(seq) for seq in re]
data = np.array(lns[:100000])
sns.histplot(data = data, binwidth = 3, kde = True)
print(np.mean(data))
print(np.median(data))
print(np.min(data))
print(np.max(data))
# Out:
# 495.51731
# 475.0
# 6
# 14595

# %%
he,re,qu = file_readers.fastq("/gpfs/commons/home/mgarbulowski/016_proj_shm/data_polyA_comparison/20250925_1858_P2S-02509-B_PBA50717_5e6e2eeb_trimmed_ca.fastq")
lns = [len(seq) for seq in re]
data = np.array(lns[:100000])
sns.histplot(data = data, binwidth = 3, kde = True)
print(np.mean(data))
print(np.median(data))
print(np.min(data))
print(np.max(data))
# Out:
# 456.0215
# 456.5
# 101
# 11234

# %%
he,re,qu = file_readers.fastq("/gpfs/commons/home/mgarbulowski/016_proj_shm/data_polyA_comparison/20251015_1800_P2S-02509-B_PBA23028_e80b6c85_trimmed.fastq")
lns = [len(seq) for seq in re]
data = np.array(lns[:100000])
sns.histplot(data = data, binwidth = 3, kde = True)
print(np.mean(data))
print(np.median(data))
print(np.min(data))
print(np.max(data))
# Out:
# 618.51382
# 632.0
# 6
# 11704

# %%
he,re,qu = file_readers.fastq("/gpfs/commons/home/mgarbulowski/016_proj_shm/data_polyA_comparison/20251015_1800_P2S-02509-B_PBA23028_e80b6c85_trimmed_ca.fastq")
lns = [len(seq) for seq in re]
data = np.array(lns[:100000])
sns.histplot(data = data, binwidth = 3, kde = True)
print(np.mean(data))
print(np.median(data))
print(np.min(data))
print(np.max(data))
# Out:
# 546.0621
# 537.0
# 101
# 8088

# %%
he,re,qu = file_readers.fastq("/gpfs/commons/home/mgarbulowski/016_proj_shm/data_polyA_comparison/20250925_1858_P2S-02509-B_PBA50717_5e6e2eeb_trimmed_ca_chopped.fastq")
lns = [len(seq) for seq in re]
data = np.array(lns[:100000])
sns.histplot(data = data, binwidth = 3, kde = True)
print(np.mean(data))
print(np.median(data))
print(np.min(data))
print(np.max(data))
# Out:
# 597.28394
# 579.0
# 291
# 14228

# %%
he,re,qu = file_readers.fastq("/gpfs/commons/home/mgarbulowski/016_proj_shm/data_polyA_comparison/20251015_1800_P2S-02509-B_PBA23028_e80b6c85_trimmed_ca_chopped.fastq")
lns = [len(seq) for seq in re]
data = np.array(lns[:100000])
sns.histplot(data = data, binwidth = 3, kde = True)
print(np.mean(data))
print(np.median(data))
print(np.min(data))
print(np.max(data))
# Out:
# 609.8414
# 570.0
# 291
# 4881
