# %%
import sys
import pandas as pd
sys.path.append('/gpfs/commons/home/mgarbulowski/homic_package/src') # to load our package
from homic import file_readers, process_data, make_plots
# Out:
# homic package imported

# %%
path_b1 = '/gpfs/commons/home/mgarbulowski/data_moumic/ERR5838516_blastn.txt'
data1 = process_data.read_n_clean_blastn(path_b1)
print(data1.iloc[:5])

path_b2 = '/gpfs/commons/home/mgarbulowski/data_moumic/ERR5838523_blastn.txt'
data2 = process_data.read_n_clean_blastn(path_b2)
print(data2.iloc[:5])

path_b3 = '/gpfs/commons/home/mgarbulowski/data_moumic/ERR5838529_blastn.txt'
data3 = process_data.read_n_clean_blastn(path_b3)
print(data3.iloc[:5])
# Out:
#            contig_id  subject_id  pident  length  evalue  bitscore  score  \
# 828424   k141_112446  CP097561.1  99.985   98746     0.0  182300.0  98700
# 559342   k141_102574  CP097561.1  99.444   68020     0.0  123500.0  66882
# 3324701   k141_90145  CP097561.1  99.894   60585     0.0  111500.0  60390
# 412492    k141_19138  CP138345.1  99.783   48489     0.0   88952.0  48169
# 828516   k141_112446  CP173167.1  93.284   58326     0.0   85918.0  46526
#
#                                              subject_title  8           9  \
# 828424   CP097561.1 Ligilactobacillus murinus ASF361 ch...  0  CP097561.1
# 559342   CP097561.1 Ligilactobacillus murinus ASF361 ch...  0  CP097561.1
# 3324701  CP097561.1 Ligilactobacillus murinus ASF361 ch...  0  CP097561.1
# 412492   CP138345.1 Ligilactobacillus murinus strain XY...  0  CP138345.1
# 828516   CP173167.1 Ligilactobacillus animalis strain D...  0  CP173167.1
#
#                             species              genus
# 828424    Ligilactobacillus murinus  Ligilactobacillus
# 559342    Ligilactobacillus murinus  Ligilactobacillus
# 3324701   Ligilactobacillus murinus  Ligilactobacillus
# 412492    Ligilactobacillus murinus  Ligilactobacillus
# 828516   Ligilactobacillus animalis  Ligilactobacillus
#           contig_id  subject_id  pident  length  evalue  bitscore   score  \
# 1577325  k141_11029  CP047057.1  99.983  501357     0.0  925400.0  501098
# 1226974    k141_651  CP047057.1  99.998  339515     0.0  626900.0  339491
# 2111982  k141_20382  CP047057.1  99.994  305915     0.0  564800.0  305856
# 1716811    k141_686  CP047057.1  99.999  269053     0.0  496800.0  269047
# 574885   k141_16327  CP047057.1  99.995  219582     0.0  405400.0  219551
#
#                                              subject_title  8           9  \
# 1577325  CP047057.1 Escherichia coli NC101 chromosome, ...  0  CP047057.1
# 1226974  CP047057.1 Escherichia coli NC101 chromosome, ...  0  CP047057.1
# 2111982  CP047057.1 Escherichia coli NC101 chromosome, ...  0  CP047057.1
# 1716811  CP047057.1 Escherichia coli NC101 chromosome, ...  0  CP047057.1
# 574885   CP047057.1 Escherichia coli NC101 chromosome, ...  0  CP047057.1
#
#                   species        genus
# 1577325  Escherichia coli  Escherichia
# 1226974  Escherichia coli  Escherichia
# 2111982  Escherichia coli  Escherichia
# 1716811  Escherichia coli  Escherichia
# 574885   Escherichia coli  Escherichia
#           contig_id  subject_id  pident  length  evalue  bitscore   score  \
# 386966   k141_48084  CP136658.1  98.503  114412     0.0  201700.0  109241
# 3403622  k141_99183  CP097561.1  99.986   98745     0.0  182300.0   98702
# 1987611  k141_42226  CP098825.1  99.642   92698     0.0  169300.0   91699
# 2251356  k141_26528  CP098825.1  99.720   73674     0.0  134900.0   73049
# 1462239  k141_57128  CP098825.1  99.658   72565     0.0  132600.0   71814
#
#                                              subject_title  8           9  \
# 386966   CP136658.1 Lactobacillus johnsonii strain GJ23...  0  CP136658.1
# 3403622  CP097561.1 Ligilactobacillus murinus ASF361 ch...  0  CP097561.1
# 1987611  CP098825.1 Paramuribaculum intestinale strain ...  0  CP098825.1
# 2251356  CP098825.1 Paramuribaculum intestinale strain ...  0  CP098825.1
# 1462239  CP098825.1 Paramuribaculum intestinale strain ...  0  CP098825.1
#
#                              species              genus
# 386966       Lactobacillus johnsonii      Lactobacillus
# 3403622    Ligilactobacillus murinus  Ligilactobacillus
# 1987611  Paramuribaculum intestinale    Paramuribaculum
# 2251356  Paramuribaculum intestinale    Paramuribaculum
# 1462239  Paramuribaculum intestinale    Paramuribaculum

# %%
make_plots.relative_abundance(data1, "ERR5838516", thr = 0.1)
make_plots.relative_abundance(data2, "ERR5838523", thr = 0.1)
make_plots.relative_abundance(data3, "ERR5838529", thr = 0.1)
